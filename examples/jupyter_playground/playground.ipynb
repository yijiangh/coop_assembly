# %%
from coop_assembly.help_functions import dropped_perpendicular_points

# %%
line1 = [[0,0,0], [1,0,0]]
line2 = [[1,0,1], [0,0,1]]

# %%
contact_pts = dropped_perpendicular_points(*line1, *line2)

# %%
contact_pts
# Out:
# [array([0.5, 0. , 0. ]), array([0.5, 0. , 1. ])]

# %%
# https://stackoverflow.com/questions/21352580/matplotlib-plotting-numerous-disconnected-line-segments-with-different-colors
# https://exnumerus.blogspot.com/2011/02/how-to-quickly-plot-multiple-line.html
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

plt.figure()
plt.subplot(1,1,1, projection='3d')

# plt.plot(*line1,'r',alpha=1.0)
# plt.plot(*line2,'y',alpha=1.0)
# ax.plot(*contact_pts,'b-',alpha=1.0)

# ax.autoscale()
# ax.margins(0.1)
